# %%
import pandas as pd 
import numpy as np
import requests 
from bs4 import BeautifulSoup
import html5lib 
import yfinance as yf
import matplotlib.pyplot as plt

# %%
tesla=yf.Ticker("TSLA")
tesla
b=tesla.history(period='max')
b.head(5)
b
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2010-06-29 00:00:00-04:00    1.266667    1.666667    1.169333    1.592667
# 2010-06-30 00:00:00-04:00    1.719333    2.028000    1.553333    1.588667
# 2010-07-01 00:00:00-04:00    1.666667    1.728000    1.351333    1.464000
# 2010-07-02 00:00:00-04:00    1.533333    1.540000    1.247333    1.280000
# 2010-07-06 00:00:00-04:00    1.333333    1.333333    1.055333    1.074000
# ...                               ...         ...         ...         ...
# 2023-03-15 00:00:00-04:00  180.800003  182.339996  176.029999  180.449997
# 2023-03-16 00:00:00-04:00  180.369995  185.809998  178.839996  184.130005
# 2023-03-17 00:00:00-04:00  184.520004  186.220001  177.330002  180.130005
# 2023-03-20 00:00:00-04:00  178.080002  186.440002  176.350006  183.250000
# 2023-03-21 00:00:00-04:00  188.279999  198.000000  188.039993  197.580002
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
make_graph=plot(Open,High,'tesla')
make_graph
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 make_graph=plot(Open,High,'tesla')
#       2 make_graph
#
# NameError: name 'plot' is not defined

# %%
GameStop=yf.Ticker("GMST")
a=GameStop.history(period='5y')
a.head(5)
# Out:
# GMST: No data found for this date range, symbol may be delisted
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []
